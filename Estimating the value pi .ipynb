# %%
import sys
import matplotlib
matplotlib.use('Agg')
import math as mt
import random
import matplotlib.pyplot as plt
# %matplotlib inline
u=[0]
v=[0]
w=[0]
z=[0]
def xyz(n):
    circle=0
    total=0
    for _ in range(n):
        x=random.uniform(-1,1)
        y=random.uniform(-1,1)
        if x**2+y**2 <= 1:
          circle=circle+1
          u.append(x)
          v.append(y)
          if y<= (-mt.sqrt(3)*x)+1:
                if y<=(mt.sqrt(3)*x)+1:
                    if y>= -1/2: 
                        total=total+1   
                        w.append(x)
                        z.append(y)
                        plt.scatter(u,v)
                        plt.scatter(w,z)
                            
    return (((3*mt.sqrt(3))/4)*(circle/total))

# %%
xyz(1000)
# Out:
# 3.3360679590965336

# %%
import sys
import matplotlib
matplotlib.use('Agg')
import math as mt
import random
import matplotlib.pyplot as plt
# %matplotlib inline
u=[0]
v=[0]
l=[0]
m=[0]
def xyz(n):
    circle=0
    total=0
    for _ in range(n):
        x=random.uniform(-mt.sqrt(3),mt.sqrt(3))
        y=random.uniform(-1,2)
        if y<= -(mt.sqrt(3)*x)+2:
            if x>= (-2+y)/mt.sqrt(3):
                        if x**2+y**2 <= 1:
                            circle=circle+1
                            l.append(x)
                            m.append(y)
                        u.append(x)
                        v.append(y)
                        plt.scatter(u,v)
                        plt.scatter(l,m)
                        total=total+1    
    return (3*(mt.sqrt(3))*(circle/total))
    plt.show()

# %%
xyz(1000)
# Out:
# 3.1548068280718833
